# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
 """Global tuple store positions to update"""
 red = (0,0)
 blue = (0,0)
 
 
 class Board:
    
     def __init__(self):
         """Instantiate and show an 8x8 Chess Board"""
         self.grid = np.zeros((8, 8, 3))
         white = (1,1,1)
         for i in range(8):
            for j in range(8):
                if ((i+j)%2):
                    self.grid[i][j] = white
         plt.imshow(self.grid)
        

     def add_red(self, row=None, col=None):
         """method input: an int row and an int col, output: places red square at input row and col"""
         self.grid[row][col] = (1,.2,0)
         red = (self.grid[row], self.grid[col])
       

     def add_blue(self, row=None, col=None):
         """method input: an int row and an int col, output: board with blue square at input row and col"""
         self.grid[row][col] = (0,1,1)
         blue = (self.grid[row], self.grid[col])

     def render(self):
         """method displays board with red and blue square at designated row/col if methods above are invoked prior"""
         plt.imshow(self.grid)
        

     def is_under_attack(self):
         """method output: boolean TRUE if blue and red squares are inline horizonally, vertically, or diagonally """
         pass

# %%
    board = Board()

# %%
board = Board()
board.add_red(6,4)
board.render()

# %%
board = Board()
board.add_red(6,4)
board.add_blue(7,3)
board.render()
